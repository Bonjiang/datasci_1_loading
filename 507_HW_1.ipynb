# %% [markdown]
# <a href="https://colab.research.google.com/github/Bonjiang/datasci_1_loading/blob/main/507_HW_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ### Loading CSV

# %% [markdown]
# ##### 1. Vegetable Components Dataset

# %%
vegetable_components = pd.read_csv('Vegetables.csv')
vegetable_components
# Out:
#                                    Name   Calories Carbohydrate   Fiber  \
# 0                             Artichoke    47 kcal       10.5 g   5.4 g
# 1                               Arugula    25 kcal        3.7 g   1.6 g
# 2                             Asparagus    20 kcal        4.0 g   2.1 g
# 3                          Bell Peppers    27 kcal        6.3 g   0.9 g
# 4                           Beet Greens    22 kcal        4.3 g   3.7 g
# 5                      Beets / Beetroot    43 kcal        9.6 g   2.8 g
# 6                              Bok Choy    13 kcal        2.2 g   1.0 g
# 7                          Bottle Gourd    14 kcal       3.39 g   0.5 g
# 8                              Broccoli    34 kcal        6.6 g   2.6 g
# 9                Broccoli Rabe (Rapini)    22 kcal        3.1 g   2.7 g
# 10                     Brussels Sprouts    43 kcal          9 g   3.8 g
# 11                     Butternut Squash    40 kcal         10 g     ~ g
# ...

# %% [markdown]
# ###### Vegetable Components Dataset - **First 10 rows**

# %%
vegetable_components [:10]
# Out:
#                       Name  Calories Carbohydrate   Fiber   Sugar      Fat  \
# 0                Artichoke   47 kcal       10.5 g   5.4 g   1.0 g    0.2 g
# 1                  Arugula   25 kcal        3.7 g   1.6 g   2.1 g    0.7 g
# 2                Asparagus   20 kcal        4.0 g   2.1 g   1.9 g    0.1 g
# 3             Bell Peppers   27 kcal        6.3 g   0.9 g     ~ g    0.2 g
# 4              Beet Greens   22 kcal        4.3 g   3.7 g   0.5 g    0.1 g
# 5         Beets / Beetroot   43 kcal        9.6 g   2.8 g   6.8 g    0.2 g
# 6                 Bok Choy   13 kcal        2.2 g   1.0 g   1.2 g    0.2 g
# 7             Bottle Gourd   14 kcal       3.39 g   0.5 g  0.02 g   0.62 g
# 8                 Broccoli   34 kcal        6.6 g   2.6 g   1.7 g    0.4 g
# 9   Broccoli Rabe (Rapini)   22 kcal        3.1 g   2.7 g   0.4 g    0.5 g
#
#    Protein  Vitamin C Vitamin K1    Folate Magnesium Manganese
# 0    3.3 g    20% RDA    18% RDA   17% RDA   15% RDA   13% RDA
# ...

# %% [markdown]
# ##### Features

# %% [markdown]
# *   Name: The name of the vegetable researched
#
# *   Calories: The amount of calories in the vegetable
#
# *   Carbohydrate: The amount of carbohydrates in the vegetable in grams
#
# *   Fiber: The amount of fiber in the vegetable in grams
#
# *   Sugar: The amount of sugar in the vegetable in grams
#
# *  Fat: The amount of fat in the vegetable in grams
#
# *   Protein: The amount of protein in the vegetable in grams
#
# * Vitamin C: The Recommended Dietary Allowance
# (RDA) percentage of Vitamin C in the vegetable
#
# *   Vitamin K1: The RDA percentage of Vitamin K1 in the vegetable
#
# *   Folate: The RDA percentage of Folate in the vegetable
#
# *   Magnesium: The RDA percentage of Magnesium in the vegetable
#
# *   Manganese: The RDA percentage of Manganese in the vegetable

# %% [markdown]
# ##### 2. New Delhi Hotel Reviews Dataset

# %%
hotel_reviews = pd.read_csv('hotel_reviews.csv')
hotel_reviews
# Out:
#       Index             Name                    Area Review_Date  \
# 0         0  Hotel The Pearl    Paharganj, New Delhi      Jul-23
# 1         1  Hotel The Pearl    Paharganj, New Delhi      Aug-23
# 2         2  Hotel The Pearl    Paharganj, New Delhi      Aug-23
# 3         3  Hotel The Pearl    Paharganj, New Delhi      Aug-23
# 4         4  Hotel The Pearl    Paharganj, New Delhi      Aug-23
# ...     ...              ...                     ...         ...
# 6996   6996  FabHotel F9 NSP  North Delhi, New Delhi      Aug-23
# 6997   6997  FabHotel F9 NSP  North Delhi, New Delhi      Jul-23
# 6998   6998  FabHotel F9 NSP  North Delhi, New Delhi      Jul-23
# 6999   6999  FabHotel F9 NSP  North Delhi, New Delhi      Jun-23
# 7000   7000  FabHotel F9 NSP  North Delhi, New Delhi      Jul-23
#
#                                Rating_attribute  Rating(Out of 10)  \
# 0                    Best budget friendly hotel                9.0
# ...

# %% [markdown]
# ##### New Delhi Hotel Reviews Dataset - **First 10 rows**

# %%
hotel_reviews [:10]
# Out:
#    Index             Name                  Area Review_Date  \
# 0      0  Hotel The Pearl  Paharganj, New Delhi      Jul-23
# 1      1  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 2      2  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 3      3  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 4      4  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 5      5  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 6      6  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 7      7  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 8      8  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 9      9  Hotel The Pearl  Paharganj, New Delhi      Aug-23
#
#                             Rating_attribute  Rating(Out of 10)  \
# 0                 Best budget friendly hotel                9.0
# 1                              Amazing place                9.0
# 2               Overall good stay. Economic.                9.0
# ...

# %% [markdown]
# ##### Features

# %% [markdown]
# * Index: A unique identifier for each review
# entry
#
# * Name: The name of the hotel that was reviewed
#
# * Area: The geographic area or city where the hotel is located
#
# * Review Date: The date when the review was posted
#
# * Rating Attribute: The aspect or attribute of the hotel being rated
#
# * Rating (Out of 10): The rating given by the reviewer for the specific attribute
#
# * Review Text: The text of the review written by the guest

# %% [markdown]
# ##### 3. Hours Studied and GPA Dataset

# %%
gpa_study_hours = pd.read_csv('gpa_study_hours.csv')
gpa_study_hours
# Out:
#       gpa  study_hours
# 0    4.00         10.0
# 1    3.80         25.0
# 2    3.93         45.0
# 3    3.40         10.0
# 4    3.20          4.0
# ..    ...          ...
# 188  3.60         24.0
# 189  3.70         12.0
# 190  3.84         15.0
# 191  3.80         10.0
# 192  3.10         15.0
#
# [193 rows x 2 columns]

# %% [markdown]
# ##### Hours Studied and GPA Dataset - **First 10 rows**

# %%
gpa_study_hours [:10]
# Out:
#     gpa  study_hours
# 0  4.00         10.0
# 1  3.80         25.0
# 2  3.93         45.0
# 3  3.40         10.0
# 4  3.20          4.0
# 5  3.52         10.0
# 6  3.68         24.0
# 7  3.40         40.0
# 8  3.70         10.0
# 9  3.75         10.0

# %% [markdown]
# ##### Features

# %% [markdown]
# * GPA: Grade point average (GPA) of the student
# * Study Hours: The amount of hours students study per week

# %% [markdown]
# ### Loading JSON

# %% [markdown]
# ##### 1. Iris Dataset

# %%
iris = pd.read_json('iris.json')
iris
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##### Iris Dataset - **First 10 rows**

# %%
iris [:10]
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa
# 5          5.4         3.9          1.7         0.4  setosa
# 6          4.6         3.4          1.4         0.3  setosa
# 7          5.0         3.4          1.5         0.2  setosa
# 8          4.4         2.9          1.4         0.2  setosa
# 9          4.9         3.1          1.5         0.1  setosa

# %% [markdown]
# ##### Features

# %% [markdown]
# *   sepalLength: The length of the iris sepal
#
# *   sepalWidth: The width of the iris sepal
#
# *   petalLength: The length of the iris petal
#
# *   petalWidth: the width of the iris petal
#
# *   Species: The species of the iris

# %% [markdown]
# ##### 2. Covid-19 Worldwide Dataset

# %%
covid_worldwide = pd.read_json('covid19_worldwide_2020.json')
covid_worldwide
# Out:
#             date  daily_confirmed_cases  daily_deaths  confirmed_cases  \
# 0     2020-03-20                      1             0                1
# 1     2020-03-21                      0             0                1
# 2     2020-03-22                      1             0                2
# 3     2020-03-23                      0             0                2
# 4     2020-03-24                      0             0                2
# ...          ...                    ...           ...              ...
# 61895 2020-02-24                     57             1              691
# 61896 2020-02-26                      0             1              691
# 61897 2020-03-10                     -9             1              696
# 61898 2020-02-20                     79             2              621
# 61899 2020-02-29                      0             2              705
#
#        deaths    geo_id
# 0           0        TD
# 1           0        TD
# 2           0        TD
# ...

# %% [markdown]
# ##### Covid-19 Worldwide Dataset - **First 10 rows**

# %%
covid_worldwide [:10]
# Out:
#         date  daily_confirmed_cases  daily_deaths  confirmed_cases  deaths  \
# 0 2020-03-20                      1             0                1       0
# 1 2020-03-21                      0             0                1       0
# 2 2020-03-22                      1             0                2       0
# 3 2020-03-23                      0             0                2       0
# 4 2020-03-24                      0             0                2       0
# 5 2020-03-25                      1             0                3       0
# 6 2020-03-26                      0             0                3       0
# 7 2020-03-27                      2             0                5       0
# 8 2020-03-28                      0             0                5       0
# 9 2020-03-29                      0             0                5       0
#
#   geo_id
# 0     TD
# 1     TD
# 2     TD
# 3     TD
# 4     TD
# 5     TD
# 6     TD
# 7     TD
# 8     TD
# 9     TD

# %% [markdown]
# ##### Features

# %% [markdown]
# * date: The date recorded to track Covid-19
#
# * daily_confirmed_cases: The amount of confirmed Covid-19 cases daily
#
# * daily_deaths: The amount of Covid-19 deaths daily
#
# * confirmed_cases: The amount of confirmed Covid-19 cases recorded
#
# * deaths: The amount of Covid-19 deaths recorded
#
# * geo_id: The geographic identifiers (GEOIDs) used to indicate the location recorded

# %% [markdown]
# ##### 3. Covid Patients (Random Sampling) Dataset

# %%
covid_patients = pd.read_json('covid.json')
covid_patients
# Out:
#        # age Sleep_problems Headache Diarrhea Abdominal_pain body_pain  \
# 0      1  19            yes      yes      yes            yes       yes
# 1      2  28            yes      yes       no             no       yes
# 2      3  40             no      yes       no             no       yes
# 3      4  62            yes      yes      yes            yes       yes
# 4      5  23            yes      yes       no             no       yes
# ..   ...  ..            ...      ...      ...            ...       ...
# 482  483  26             no      yes       no             no        no
# 483  484  51             no       no       no             no       yes
# 484  485  32             no       no       no             no       yes
# 485  486  30             no       no       no             no       yes
# 486  487  27             no      yes       no             no       yes
#
#     Body_discoloration Cough Fever  ... runny_nose Chest_pain  \
# ...

# %% [markdown]
# ##### Covid Patients (Random Sampling) Dataset - **First 10 rows**

# %%
covid_patients [:10]
# Out:
#     # age Sleep_problems Headache Diarrhea Abdominal_pain body_pain  \
# 0   1  19            yes      yes      yes            yes       yes
# 1   2  28            yes      yes       no             no       yes
# 2   3  40             no      yes       no             no       yes
# 3   4  62            yes      yes      yes            yes       yes
# 4   5  23            yes      yes       no             no       yes
# 5   6  34             no      yes      yes             no       yes
# 6   7  39            yes      yes       no             no       yes
# 7   8  46            yes      yes       no             no       yes
# 8   9  20             no      yes       no             no       yes
# 9  10  27            yes       no       no             no       yes
#
#   Body_discoloration Cough Fever  ... runny_nose Chest_pain  \
# 0                 no    no    no  ...         no         no
# 1                 no   yes    no  ...         no         no
# ...

# %% [markdown]
# ##### Features

# %% [markdown]
# * '#': A unique identifer for the patient interviewed
#
# * age: the age of the patient interviewed
#
# * Sleep_problems: A yes or no response to whether the patient had issues with sleeping
#
# * Headache: A yes or no response to whether the patient had a headache
#
# * Diarrhea: A yes or no response to whether the patient had diarrhea
#
# * Abdominal_pain: A yes or no response to whether the patient had abdominal pain
#
# * body_pain: A yes or no response to whether the patient had body pain
#
# * Body_discoloration A yes or no response to whether the patient had body discoloration
#
# * Cough: A yes or no response to whether the patient had a cough
#
# * Fever: A yes or no response to whether the patient had issues a fever
#
# * Ague: A yes or no response to whether the patient had ague
#
# * Sore_throat: A yes or no response to whether the patient had a sore throat
#
# * Fatigue: A yes or no response to whether the patient had fatigue
#
# * runny_nose: A yes or no response to whether the patient had a runny nose
#
# * Chest_pain: A yes or no response to whether the patient had chest pain
#
# * Decreased_appetite: A yes or no response to whether the patient had decreased appetite
#
# * Vomit: A yes or no response to whether the patient vomitted
#
# * Nausea: A yes or no response to whether the patient had nausea
#
# * Sneezing: A yes or no response to whether the patient was sneezing
#
# * Shortness_of_breath: A yes or no response to whether the patient had shortness of breath
#
# * Loss_of_smell: A yes or no response to whether the patient had loss of smell
#
# * Loss_of_taste: A yes or no response to whether the patient had loss of taste
#
# * Urticaria: A yes or no response to whether the patient had urticaria

# %% [markdown]
# ### Loading XLSX

# %% [markdown]
# ##### 1. Chipotle Stores Dataset

# %%
chipotle_stores = pd.read_excel ('chipotle_stores.xlsx')
chipotle_stores
# Out:
#              state          location  \
# 0          Alabama            Auburn
# 1          Alabama        Birmingham
# 2          Alabama        Birmingham
# 3          Alabama        Birmingham
# 4          Alabama           Cullman
# ...            ...               ...
# 2624     Wisconsin  Pleasant Prairie
# 2625     Wisconsin         Wauwatosa
# 2626  North Dakota             Fargo
# 2627  North Dakota             Fargo
# 2628       Wyoming          Cheyenne
#
#                                              address   latitude   longitude
# 0             346 W Magnolia Ave Auburn, AL 36832 US  32.606813  -85.487328
# 1              300 20th St S Birmingham, AL 35233 US  33.509721  -86.802756
# 2             3220 Morrow Rd Birmingham, AL 35235 US  33.595581  -86.647437
# 3           4719 Highway 280 Birmingham, AL 35242 US  33.422582  -86.698279
# 4          1821 Cherokee Ave SW Cullman, AL 35055 US  34.154134  -86.841220
# ...

# %% [markdown]
# Chipotle Stores Dataset -**First 10 rows**

# %%
chipotle_stores [:10]
# Out:
#      state    location                                            address  \
# 0  Alabama      Auburn             346 W Magnolia Ave Auburn, AL 36832 US
# 1  Alabama  Birmingham              300 20th St S Birmingham, AL 35233 US
# 2  Alabama  Birmingham             3220 Morrow Rd Birmingham, AL 35235 US
# 3  Alabama  Birmingham           4719 Highway 280 Birmingham, AL 35242 US
# 4  Alabama     Cullman          1821 Cherokee Ave SW Cullman, AL 35055 US
# 5  Alabama      Hoover            1759 Montgomery Hwy Hoover, AL 35244 US
# 6  Alabama  Huntsville  5900 University Dr NW Ste D2 Huntsville, AL 35...
# 7  Alabama      Mobile              3871 Airport Blvd Mobile, AL 36608 US
# 8  Alabama      Mobile         7765 Airport Blvd D100 Mobile, AL 36608 US
# 9  Alabama  Montgomery    2560 Berryhill Rd Ste C Montgomery, AL 36117 US
#
#     latitude  longitude
# 0  32.606813 -85.487328
# 1  33.509721 -86.802756
# 2  33.595581 -86.647437
# 3  33.422582 -86.698279
# 4  34.154134 -86.841220
# ...

# %% [markdown]
# ##### Features

# %% [markdown]
# * State: The state of every Chipotle restaurant within the United States
#
# * Location: The location of every Chipotle restaurant within the United States
#
# * Address: The address of every Chipotle restaurant within the United States
#
# * Latitude: The latitude coordinates of every Chipotle restaurant within the United States
#
# * Longitude: The longitude coordinates of every Chipotle restaurant within the United States

# %% [markdown]
# ##### 2. 2020 Netflix Review Dataset

# %%
netflix_revenue = pd.read_excel('DataNetflixRevenue2020_V2.xlsx')
netflix_revenue
# Out:
#                                Area      Years     Revenue
# 0          United States and Canada  Q1 - 2018  1976157000
# 1   Europe,  Middle East and Africa  Q1 - 2018   886649000
# 2                     Latin America  Q1 - 2018   540182000
# 3                      Asia-Pacific  Q1 - 2018   199117000
# 4          United States and Canada  Q2 - 2018  2049546000
# 5   Europe,  Middle East and Africa  Q2 - 2018   975497000
# 6                     Latin America  Q2 - 2018   568071000
# 7                      Asia-Pacific  Q2 - 2018   221252000
# 8          United States and Canada  Q3 - 2018  2094850000
# 9   Europe,  Middle East and Africa  Q3 - 2018  1004749000
# 10                    Latin America  Q3 - 2018   562307000
# 11                     Asia-Pacific  Q3 - 2018   248691000
# 12         United States and Canada  Q4 - 2018  2160979000
# 13  Europe,  Middle East and Africa  Q4 - 2018  1096812000
# 14                    Latin America  Q4 - 2018   567137000
# ...

# %% [markdown]
# 2020 Netflix Review Dataset - **First 10 rows**

# %%
netflix_revenue [:10]
# Out:
#                               Area      Years     Revenue
# 0         United States and Canada  Q1 - 2018  1976157000
# 1  Europe,  Middle East and Africa  Q1 - 2018   886649000
# 2                    Latin America  Q1 - 2018   540182000
# 3                     Asia-Pacific  Q1 - 2018   199117000
# 4         United States and Canada  Q2 - 2018  2049546000
# 5  Europe,  Middle East and Africa  Q2 - 2018   975497000
# 6                    Latin America  Q2 - 2018   568071000
# 7                     Asia-Pacific  Q2 - 2018   221252000
# 8         United States and Canada  Q3 - 2018  2094850000
# 9  Europe,  Middle East and Africa  Q3 - 2018  1004749000

# %% [markdown]
# ##### Features

# %% [markdown]
# * Area: The area or regions that brought in revenue for Netflix
#
# * Years: The quarter and year that brought in revenue for Netflix
#
# * Revenue: The revenue amount brought in recorded

# %% [markdown]
# ##### 3. Barcelona Life Expectancy Dataset

# %%
life_expectancy = pd.read_excel('life_expectancy.xlsx')
life_expectancy
# Out:
#                                       Neighborhood  2006-2010  2007-2011  \
# 0                                         el Raval       87.5       84.9
# 1                                  el Barri Gòtic       88.0       84.3
# 2                                   la Barceloneta       88.2       85.3
# 3            Sant Pere, Santa Caterina i la Ribera       88.9       85.9
# 4                                    el Fort Pienc       89.7       87.1
# ..                                             ...        ...        ...
# 141  Diagonal Mar i el Front Marítim del Poblenou       82.1       80.9
# 142                         el Besòs i el Maresme       80.2       78.1
# 143                       Provençals del Poblenou       80.4       78.8
# 144                     Sant Martí de Provençals       81.9       79.5
# 145                            la Verneda i la Pau       82.0       79.7
#
#      2008-2012  2009-2013  2010-2014  Gender
# 0         84.7       84.9       85.3  Female
# ...

# %% [markdown]
# ##### Barcelona Life Expectancy Dataset - **First 10 rows**

# %%
life_expectancy [:10]
# Out:
#                             Neighborhood  2006-2010  2007-2011  2008-2012  \
# 0                               el Raval       87.5       84.9       84.7
# 1                        el Barri Gòtic       88.0       84.3       84.4
# 2                         la Barceloneta       88.2       85.3       84.4
# 3  Sant Pere, Santa Caterina i la Ribera       88.9       85.9       86.1
# 4                          el Fort Pienc       89.7       87.1       87.2
# 5                    la Sagrada Família       88.9       86.6       86.8
# 6                 la Dreta de l'Eixample       87.0       85.0       85.1
# 7        l'Antiga Esquerra de l'Eixample       88.9       86.4       86.3
# 8         la Nova Esquerra de l'Eixample       90.0       87.4       87.5
# 9                            Sant Antoni       89.0       86.3       86.5
#
#    2009-2013  2010-2014  Gender
# 0       84.9       85.3  Female
# 1       87.5       84.4  Female
# 2       86.3       84.7  Female
# ...

# %% [markdown]
# ##### Features

# %% [markdown]
# * Neigborhood: The Barcelona neighborhood researched for life expectancy
#
# * Interval of years recorded: The life expectancy of those that lived in Barcelona over the years of 2006-2013
#
# * Gender: The gender recorded for the life expectancy over the years of 2006-2013
